# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, confusion_matrix, roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# %%
import zipfile
import pandas as pd

# %%
import os

print(os.listdir(r"C:\Users\NITIKA KUMARI\Downloads"))
# Out:
# ['.ipynb_checkpoints', '1 mark html css.pdf', '10 Meta AI.html', '10 Meta AI_files', '10_svm.ipynb', '11.1- Adaboost MAth intuition.pdf', '11_random_forest.ipynb', '172427893_3_pg11.png', '172448470_3_pg15.png', '77906409598187_77906427612108 (2).jpg', '9_decision_tree.ipynb', 'Aaarushi.pdf.png', 'academic Stress level - maintainance 1.csv', 'accenture certificate.pdf', 'aclImdb_v1.tar.gz', 'AdaBoost.ipynb', 'admission fee slip cusb.pdf', 'Admit card.png', 'AdmitCard.pdf', 'Advanced Machine Learning with Python.pdf', 'Ai ml roadmap.png', 'AI MoodMate-1 (1).pdf', 'AI Primer Certification.pdf', 'AI_CNN-Based Music Instrument Recognition System.docx', 'AI_CNN-Based Music Instrument Recognition System.pdf', 'Anaconda3-2024.10-1-Windows-x86_64.exe', 'animate.mp4', 'Anime story', 'ANNUAL ACADEMIC CALENDAR 2025-26 (1) (1).xlsx', 'archive (1).zip', 'archive (10).zip', 'archive (11).zip', 'archive (12).zip', 'archive (2).zip', 'archive (3).zip', 'archive (4).zip', 'archive (5).zip', 'archive 
# ...

# %%
import zipfile

zip_path = r"C:\Users\NITIKA KUMARI\Downloads\heart+disease (2).zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("heart_dataset")

print("Extraction completed")
# Out:
# Extraction completed

# %%
zip_path = r"C:\Users\NITIKA KUMARI\Downloads\heart+disease (2).zip"

# %%
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("heart_dataset")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\NITIKA KUMARI\Advance_ml SM

# %%
import zipfile
import pandas as pd

zip_path = r"C:\Users\NITIKA KUMARI\Downloads\heart+disease (2).zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("heart_dataset")

df = pd.read_csv("heart_dataset/processed.cleveland.data", header=None)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 zip_ref.extractall("Advance_ml SM/heart+disease.zip")
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1744, in ZipFile.extractall(self, path, members, pwd)
#    1741     path = os.fspath(path)
#    1743 for zipinfo in members:
# -> 1744     self._extract_member(zipinfo, path, pwd)
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1800, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1797         os.mkdir(targetpath)
#    1798     return targetpath
# -> 1800 with self.open(member, pwd=pwd) as source, \
#    1801      open(targetpath, "wb") as target:
#    1802     shutil.copyfileobj(source, target)
#    1804 return targetpath
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1591, in ZipFile.open(self, name, mode, pwd, force_zip64)
# ...

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    random_state=42
)

rf.fit(X_train, y_train)

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:,1]

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:,1]

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:,1]

# %%
recall = recall_score(y_test, y_pred)

# %%
f1 = f1_score(y_test, y_pred)

# %%
cm = confusion_matrix(y_test, y_pred)

TN = cm[0,0]
FP = cm[0,1]

specificity = TN / (TN + FP)

# %%
roc_auc = roc_auc_score(y_test, y_prob)

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Specificity:", specificity)
print("ROC-AUC:", roc_auc)

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label="Random Forest")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
